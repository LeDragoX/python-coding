# %% [markdown]
# # Projeto de Regressão Logística
#
#
# Neste projeto estaremos trabalhando com um conjunto de dados falso de publicidade, indicando se um usuário de internet específico clicou ou não em uma propaganda. Vamos tentar criar um modelo que preveja se clicará ou não em um anúncio baseado nos recursos desse usuário.
#
# Este conjunto de dados contém os seguintes recursos:
#
# * 'Daily Time Spent on Site': tempo no site em minutos.
# * 'Age': idade do consumidor.
# * 'Area Income': Média da renda do consumidor na região.
# * 'Daily Internet Usage': Média em minutos por dia que o consumidor está na internet.
# * 'Ad Topic Line': Título do anúncio.
# * 'City': Cidade do consumidor.
# * 'Male': Se o consumidor era ou não masculino.
# * 'Country': País do consumidor.
# * 'Timestamp': hora em que o consumidor clicou no anúncio ou janela fechada.
# * 'Clicked on Ad'': 0 ou 1 indicam se clicou ou não no anúncio. (0 = NÃO CLICOU, 1 = CLICOU)
#
#
#
# ** Importe algumas bibliotecas que você acha que você precisará **

# %% [markdown]
# ## 1. Instalar bibliotecas

# %%
# !pip install pandas --upgrade
# !pip install seaborn --upgrade
# !pip install sklearn --upgrade
# !pip install matplotlib --upgrade
# Out:
# Requirement already satisfied: pandas in /home/ledragox/anaconda3/lib/python3.8/site-packages (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from pandas) (1.20.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: seaborn in /home/ledragox/anaconda3/lib/python3.8/site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from seaborn) (1.20.1)
# Requirement already satisfied: pandas>=0.23 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: matplotlib>=2.2 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: scipy>=1.0 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from seaborn) (1.6.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: six in /home/ledragox/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Requirement already satisfied: sklearn in /home/ledragox/anaconda3/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /home/ledragox/anaconda3/lib/python3.8/site-packages (from sklearn) (0.24.1)
# Requirement already satisfied: scipy>=0.19.1 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.6.2)
# Requirement already satisfied: joblib>=0.11 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (2.2.0)
# Requirement already satisfied: numpy>=1.13.3 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.20.1)
# Requirement already satisfied: matplotlib in /home/ledragox/anaconda3/lib/python3.8/site-packages (3.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: numpy>=1.16 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from matplotlib) (1.20.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ledragox/anaconda3/lib/python3.8/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: six in /home/ledragox/anaconda3/lib/python3.8/site-packages (from cycler>=0.10->matplotlib) (1.16.0)

# %% [markdown]
# ## 2. Importar bibliotecas

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import sklearn.metrics as metrics
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3. Obter dados
# ** Leia o arquivo advertising.csv e grave-o em um DataFrame chamado ad_data. **

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# Arquivo local
ad_data = pd.read_csv("data/advertising.csv")

# %% [markdown]
# ### ** 3.1 Verifique o cabeçalho do ad_data **

# %%
ad_data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# 1  2016-04-04 01:39:02              0
# 2  2016-03-13 20:35:42              0
# 3  2016-01-10 02:31:19              0
# 4  2016-06-03 03:36:18              0

# %% [markdown]
# ### ** 3.2 Comandos. que refletem os resultados abaixo **

# %%
ad_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
ad_data.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# 75%              218.792500     1.000000        1.00000
# max              269.960000     1.000000        1.00000

# %% [markdown]
# ## 4. Análise de dados exploratória
#
# Vamos usar Seaborn para explorar os dados!
#
# Tente recriar os gráficos abaixo.
#
# ** Crie um histograma de "Age" **

# %%
sns.displot(data=ad_data, x='Age', bins=30, color=(0.25, 1, 0.25))

# %% [markdown]
# ### ** 4.1 Crie um joinplot mostrando "Area Income" versus "Age" **

# %%
sns.jointplot(data=ad_data, x='Age', y='Area Income', color=(0.25, 1, 0.25))
# Consegue visualizar algo interessante, mas não é necessário abaixo
sns.jointplot(data=ad_data, x='Age', y='Area Income', color=(0.25, 1, 0.25), hue='Clicked on Ad')

# %% [markdown]
# ### ** 4.2 Crie um jointplot que mostre as distribuições KDE do "Daily Time spent" no site vs "Age". **

# %%
sns.jointplot(data=ad_data, x='Age', y='Daily Time Spent on Site', kind='kde', fill=True, color=(0.25, 1, 0.25))

# %% [markdown]
# ### ** 4.3 Crie um jointplot do 'Daily Time Spent on Site' vs. 'Daily Internet Usage'**

# %%
sns.jointplot(data=ad_data, x='Daily Time Spent on Site', y= 'Daily Internet Usage', color=(0.0, 0.5, 0.0))

# %% [markdown]
# ### ** 4.4 Finalmente, crie um parplot com o matiz definido pelo recurso de coluna 'Clicked on Ad'. **

# %%
sns.pairplot(data=ad_data, hue='Clicked on Ad', diag_kind='hist', palette=["blue", "green"])

# %% [markdown]
# ## 5 Regressão Logística
#
# Agora é hora de quebrar nossos dados em treino e teste e fitar nosso modelo.
#
# Você terá a liberdade aqui para escolher colunas em que deseja treinar!

# %% [markdown]
# ### ** 5.1 Divida os dados em conjunto de treinamento e conjunto de testes usando train_test_split **

# %%
# Separate info into X and Y 
# Y - value we want to discover
y = ad_data["Age"]

# %%
# X - the remaining
x = ad_data.drop("Age", axis=1)

# %%
x_train_ad, x_test_ad, y_train_ad, y_test_ad = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
x_train_ad.shape
# Out:
# (700, 9)

# %%
y_train_ad.shape
# Out:
# (700,)

# %%
x_test_ad.shape
# Out:
# (300, 9)

# %%
y_test_ad.shape
# Out:
# (300,)

# %% [markdown]
# ### ** 5.2 Treine e ajuste um modelo de regressão logística no conjunto de treinamento. **

# %%
logisticregression_model = LogisticRegression()

# %%
logisticregression_model.fit(x_train_ad, y_train_ad)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_103506/1840393696.py in <module>
# ----> 1 logisticregression_model.fit(x_train_ad, y_train_ad)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1342             _dtype = [np.float64, np.float32]
#    1343
# -> 1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     812         raise ValueError("y cannot be None")
#     813
# --> 814     X = check_array(X, accept_sparse=accept_sparse,
#     815                     accept_large_sparse=accept_large_sparse,
#     816                     dtype=dtype, order=order, copy=copy,
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     614                     array = array.astype(dtype, casting="unsafe", copy=False)
#     615                 else:
# --> 616                     array = np.asarray(array, order=order, dtype=dtype)
#     617             except ComplexWarning as complex_warning:
#     618                 raise ValueError("Complex data not supported\n"
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1991
#    1992     def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1993         return np.asarray(self._values, dtype=dtype)
#    1994
#    1995     def __array_wrap__(
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: 'Balanced heuristic approach'

# %% [markdown]
# ## 6 Previsões e avaliações
# ** Agora preveja valores para os dados de teste. **

# %%
predict_logisticregression = logisticregression_model.predict(x_test_ad)

percentage_logisticregression = metrics.r2_score(y_test_ad, predict_logisticregression)
print("Linear Regression:", percentage_logisticregression)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# /tmp/ipykernel_103506/982404497.py in <module>
# ----> 1 predict_logisticregression = logisticregression_model.predict(x_test_ad)
#       2
#       3 percentage_logisticregression = metrics.r2_score(y_test_ad, predict_logisticregression)
#       4 print("Linear Regression:", percentage_logisticregression)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     307             Predicted class label per sample.
#     308         """
# --> 309         scores = self.decision_function(X)
#     310         if len(scores.shape) == 1:
#     311             indices = (scores > 0).astype(int)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in decision_function(self, X)
#     280             class would be predicted.
#     281         """
# --> 282         check_is_fitted(self)
#     283
#     284         X = check_array(X, accept_sparse='csr')
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1039
#    1040     if not attrs:
# -> 1041         raise NotFittedError(msg % {'name': type(estimator).__name__})
#    1042
#    1043
#
# NotFittedError: This LogisticRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %% [markdown]
# ### ** 6.1 Crie um relatório de classificação para o modelo. **

# %%
aux_table = pd.DataFrame()
aux_table['Y Test Ad'] = y_test_ad
aux_table['Logistic Regression'] = predict_logisticregression
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_103506/2839164960.py in <module>
#       1 aux_table = pd.DataFrame()
#       2 aux_table['Y Test Ad'] = y_test_ad
# ----> 3 aux_table['Logistic Regression'] = predict_logisticregression
#
# NameError: name 'predict_logisticregression' is not defined

# %%
plt.figure(figsize=(15, 7))
sns.lineplot(data=aux_table)
plt.show()

# %%
# Performance do modelo nos dados de teste
print("Avaliação do Modelo nos Dados de Teste")
print(classification_report(y_test_ad, predict_logisticregression))
# Out:
# Avaliação do Modelo nos Dados de Teste
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_103506/613557769.py in <module>
#       1 # Performance do modelo nos dados de teste
#       2 print("Avaliação do Modelo nos Dados de Teste")
# ----> 3 print(classification_report(y_test_ad, predict_logisticregression))
#
# NameError: name 'predict_logisticregression' is not defined
